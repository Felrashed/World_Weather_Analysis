# %%
#Import the dependencies 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitutides and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Create a list that holds the cities we find
cities = []
#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then add it to the list established above for cities
    if city not in cities:
        cities.append(city)
        
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 772

# %%
#import the requests library
import requests

# %%
#import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create endpoint URL with each city and define city_weather as a function of each URL
city_url = url + "&q=" + city.replace(" ", "+")
city_weather = requests.get(city_url).json()

# %%
#Create an empty list to hold the weather data.
city_data = []
#Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create the counters
record_count = 1
set_count = 1

#Loop through all the cities in our list
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes 
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | chokurdakh
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | meulaboh
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | golspie
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | ust-nera
# Processing Record 11 of Set 1 | kozulka
# Processing Record 12 of Set 1 | kodiak
# Processing Record 13 of Set 1 | gambela
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | taltal
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 1 | luderitz
# Processing Record 22 of Set 1 | olafsvik
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | airai
# Processing Record 25 of Set 1 | tutoia
# Processing Record 26 of Set 1 | hay river
# Processing Record 27 of Set 1 | umtata
# Processing Record 28 of Set 1 | redmond
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | vardo
# Processing Record 31 of Set 1 | caravelas
# Processing Record 32 of Set 1 | myitkyina
# Processing Record 33 of Set 1 | ereymentau
# Processing Record 34 of Set 1 | mahebourg
# Processing Record 35 of Set 1 | montepuez
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | khatanga
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | kuybysheve
# Processing Record 40 of Set 1 | saint george
# Processing Record 41 of Set 1 | bokspits
# City not found. Skipping...
# Processing Record 42 of Set 1 | ponta do sol
# Processing Record 43 of Set 1 | shankargarh
# Processing Record 44 of Set 1 | tuatapere
# Processing Record 45 of Set 1 | klaksvik
# Processing Record 46 of Set 1 | apricena
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | kichmengskiy gorodok
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | pemangkat
# Processing Record 1 of Set 2 | mahadday weyne
# City not found. Skipping...
# Processing Record 2 of Set 2 | maghama
# City not found. Skipping...
# Processing Record 3 of Set 2 | saldanha
# Processing Record 4 of Set 2 | syracuse
# Processing Record 5 of Set 2 | torbay
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | chuy
# Processing Record 8 of Set 2 | fortuna
# Processing Record 9 of Set 2 | orange
# Processing Record 10 of Set 2 | saint-leu
# Processing Record 11 of Set 2 | kieta
# Processing Record 12 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 2 | cockburn town
# Processing Record 14 of Set 2 | ilulissat
# Processing Record 15 of Set 2 | kasempa
# Processing Record 16 of Set 2 | kresna
# Processing Record 17 of Set 2 | baicheng
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | carnarvon
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | xiaoyi
# Processing Record 24 of Set 2 | ribeira grande
# Processing Record 25 of Set 2 | cabo san lucas
# Processing Record 26 of Set 2 | saskylakh
# Processing Record 27 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 28 of Set 2 | belmonte
# Processing Record 29 of Set 2 | tlaxiaco
# City not found. Skipping...
# Processing Record 30 of Set 2 | akdepe
# Processing Record 31 of Set 2 | faanui
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | kaitong
# Processing Record 34 of Set 2 | ostrovnoy
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | puerto leguizamo
# Processing Record 37 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 2 | barra patuca
# Processing Record 39 of Set 2 | clyde river
# Processing Record 40 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 41 of Set 2 | la ronge
# Processing Record 42 of Set 2 | messina
# Processing Record 43 of Set 2 | gewane
# Processing Record 44 of Set 2 | arraial do cabo
# Processing Record 45 of Set 2 | alofi
# Processing Record 46 of Set 2 | tasiilaq
# Processing Record 47 of Set 2 | shebunino
# Processing Record 48 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 2 | geraldton
# Processing Record 50 of Set 2 | umm lajj
# Processing Record 1 of Set 3 | hilo
# Processing Record 2 of Set 3 | jiangyou
# Processing Record 3 of Set 3 | mezen
# Processing Record 4 of Set 3 | quelimane
# Processing Record 5 of Set 3 | hobart
# Processing Record 6 of Set 3 | qaanaaq
# Processing Record 7 of Set 3 | moerai
# Processing Record 8 of Set 3 | isangel
# Processing Record 9 of Set 3 | namibe
# Processing Record 10 of Set 3 | maridi
# Processing Record 11 of Set 3 | nchelenge
# Processing Record 12 of Set 3 | namatanai
# Processing Record 13 of Set 3 | atambua
# Processing Record 14 of Set 3 | asfi
# Processing Record 15 of Set 3 | aquin
# Processing Record 16 of Set 3 | saint anthony
# Processing Record 17 of Set 3 | bengkulu
# Processing Record 18 of Set 3 | san ignacio
# Processing Record 19 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 20 of Set 3 | shingu
# Processing Record 21 of Set 3 | ancud
# Processing Record 22 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 23 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 3 | pangnirtung
# Processing Record 25 of Set 3 | waipawa
# Processing Record 26 of Set 3 | iqaluit
# Processing Record 27 of Set 3 | palauig
# Processing Record 28 of Set 3 | hofn
# Processing Record 29 of Set 3 | mount isa
# Processing Record 30 of Set 3 | touros
# Processing Record 31 of Set 3 | niteroi
# Processing Record 32 of Set 3 | hambantota
# Processing Record 33 of Set 3 | coahuayana
# Processing Record 34 of Set 3 | deputatskiy
# Processing Record 35 of Set 3 | broken hill
# Processing Record 36 of Set 3 | umba
# Processing Record 37 of Set 3 | bluff
# Processing Record 38 of Set 3 | busselton
# Processing Record 39 of Set 3 | rumonge
# Processing Record 40 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 3 | kruisfontein
# Processing Record 42 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 3 | san rafael
# Processing Record 44 of Set 3 | new norfolk
# Processing Record 45 of Set 3 | tiksi
# Processing Record 46 of Set 3 | narsaq
# Processing Record 47 of Set 3 | rocha
# Processing Record 48 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 3 | rawson
# Processing Record 50 of Set 3 | san cristobal
# Processing Record 1 of Set 4 | sao joao da barra
# Processing Record 2 of Set 4 | victoria
# Processing Record 3 of Set 4 | maksatikha
# Processing Record 4 of Set 4 | port hawkesbury
# Processing Record 5 of Set 4 | krasnyy yar
# Processing Record 6 of Set 4 | werder
# Processing Record 7 of Set 4 | vanderhoof
# Processing Record 8 of Set 4 | roma
# Processing Record 9 of Set 4 | turbat
# Processing Record 10 of Set 4 | manzhouli
# Processing Record 11 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 4 | churachandpur
# Processing Record 13 of Set 4 | upernavik
# Processing Record 14 of Set 4 | marzuq
# Processing Record 15 of Set 4 | atherton
# Processing Record 16 of Set 4 | ranong
# Processing Record 17 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 4 | oranjemund
# Processing Record 19 of Set 4 | saint-philippe
# Processing Record 20 of Set 4 | labuan
# Processing Record 21 of Set 4 | castro
# Processing Record 22 of Set 4 | sechura
# Processing Record 23 of Set 4 | ayolas
# Processing Record 24 of Set 4 | tuktoyaktuk
# Processing Record 25 of Set 4 | sambava
# Processing Record 26 of Set 4 | san carlos
# Processing Record 27 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 4 | phan thiet
# Processing Record 29 of Set 4 | husavik
# Processing Record 30 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 4 | ledegem
# Processing Record 32 of Set 4 | egtved
# Processing Record 33 of Set 4 | westerly
# Processing Record 34 of Set 4 | alice springs
# Processing Record 35 of Set 4 | hualmay
# Processing Record 36 of Set 4 | guane
# Processing Record 37 of Set 4 | havre-saint-pierre
# Processing Record 38 of Set 4 | kijang
# Processing Record 39 of Set 4 | pevek
# Processing Record 40 of Set 4 | dauphin
# Processing Record 41 of Set 4 | buribay
# Processing Record 42 of Set 4 | evensk
# Processing Record 43 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 4 | kavieng
# Processing Record 45 of Set 4 | pisco
# Processing Record 46 of Set 4 | muros
# Processing Record 47 of Set 4 | ruidoso
# Processing Record 48 of Set 4 | tawau
# Processing Record 49 of Set 4 | nirasaki
# Processing Record 50 of Set 4 | zoetermeer
# Processing Record 1 of Set 5 | vila franca do campo
# Processing Record 2 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 5 | vao
# Processing Record 4 of Set 5 | caohai
# Processing Record 5 of Set 5 | lagoa
# Processing Record 6 of Set 5 | kupang
# Processing Record 7 of Set 5 | kaoma
# Processing Record 8 of Set 5 | bako
# Processing Record 9 of Set 5 | omboue
# Processing Record 10 of Set 5 | hit
# Processing Record 11 of Set 5 | tukrah
# Processing Record 12 of Set 5 | slave lake
# Processing Record 13 of Set 5 | buala
# Processing Record 14 of Set 5 | lasa
# Processing Record 15 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 16 of Set 5 | ambovombe
# Processing Record 17 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 18 of Set 5 | provideniya
# Processing Record 19 of Set 5 | ust-ishim
# Processing Record 20 of Set 5 | east millcreek
# Processing Record 21 of Set 5 | cortland
# Processing Record 22 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 5 | klyuchi
# Processing Record 24 of Set 5 | hutchinson
# Processing Record 25 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 5 | cayenne
# Processing Record 27 of Set 5 | karratha
# Processing Record 28 of Set 5 | komsomolskiy
# Processing Record 29 of Set 5 | merauke
# Processing Record 30 of Set 5 | raudeberg
# Processing Record 31 of Set 5 | dubbo
# Processing Record 32 of Set 5 | tahe
# Processing Record 33 of Set 5 | sembakung
# Processing Record 34 of Set 5 | banda aceh
# Processing Record 35 of Set 5 | balkhash
# Processing Record 36 of Set 5 | goderich
# Processing Record 37 of Set 5 | sioux lookout
# Processing Record 38 of Set 5 | trindade
# Processing Record 39 of Set 5 | calama
# Processing Record 40 of Set 5 | dikson
# Processing Record 41 of Set 5 | kaeo
# Processing Record 42 of Set 5 | cherskiy
# Processing Record 43 of Set 5 | itarema
# Processing Record 44 of Set 5 | walla walla
# Processing Record 45 of Set 5 | bardiyah
# Processing Record 46 of Set 5 | norman wells
# Processing Record 47 of Set 5 | margate
# Processing Record 48 of Set 5 | bonfim
# Processing Record 49 of Set 5 | sao mateus do sul
# Processing Record 50 of Set 5 | kahului
# Processing Record 1 of Set 6 | westport
# Processing Record 2 of Set 6 | kaitangata
# Processing Record 3 of Set 6 | hasaki
# Processing Record 4 of Set 6 | lebu
# Processing Record 5 of Set 6 | acajutla
# Processing Record 6 of Set 6 | geresk
# City not found. Skipping...
# Processing Record 7 of Set 6 | bombay
# Processing Record 8 of Set 6 | healdsburg
# Processing Record 9 of Set 6 | nichinan
# Processing Record 10 of Set 6 | acarau
# Processing Record 11 of Set 6 | krasnoarmeyskoye
# Processing Record 12 of Set 6 | martapura
# Processing Record 13 of Set 6 | lavrentiya
# Processing Record 14 of Set 6 | trincomalee
# Processing Record 15 of Set 6 | puerto del rosario
# Processing Record 16 of Set 6 | saint-paul
# Processing Record 17 of Set 6 | huautla
# Processing Record 18 of Set 6 | burica
# City not found. Skipping...
# Processing Record 19 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 20 of Set 6 | road town
# Processing Record 21 of Set 6 | elko
# Processing Record 22 of Set 6 | qaqortoq
# Processing Record 23 of Set 6 | nerchinskiy zavod
# Processing Record 24 of Set 6 | puerto quijarro
# Processing Record 25 of Set 6 | ishinomaki
# Processing Record 26 of Set 6 | dhone
# Processing Record 27 of Set 6 | fare
# Processing Record 28 of Set 6 | itaperuna
# Processing Record 29 of Set 6 | broome
# Processing Record 30 of Set 6 | genhe
# Processing Record 31 of Set 6 | bambous virieux
# Processing Record 32 of Set 6 | aksu
# Processing Record 33 of Set 6 | grand gaube
# Processing Record 34 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 35 of Set 6 | atasu
# Processing Record 36 of Set 6 | lesogorsk
# Processing Record 37 of Set 6 | fort nelson
# Processing Record 38 of Set 6 | inuvik
# Processing Record 39 of Set 6 | adrar
# Processing Record 40 of Set 6 | atar
# Processing Record 41 of Set 6 | kaabong
# Processing Record 42 of Set 6 | san quintin
# Processing Record 43 of Set 6 | ukiah
# Processing Record 44 of Set 6 | sinop
# Processing Record 45 of Set 6 | hafizabad
# Processing Record 46 of Set 6 | snina
# Processing Record 47 of Set 6 | mar del plata
# Processing Record 48 of Set 6 | maragogipe
# Processing Record 49 of Set 6 | kushmurun
# Processing Record 50 of Set 6 | nizhniy kuranakh
# Processing Record 1 of Set 7 | ipixuna
# Processing Record 2 of Set 7 | zhigalovo
# Processing Record 3 of Set 7 | nianzishan
# Processing Record 4 of Set 7 | sorland
# Processing Record 5 of Set 7 | kaduqli
# Processing Record 6 of Set 7 | ossora
# Processing Record 7 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 7 | sarangani
# Processing Record 9 of Set 7 | sabha
# Processing Record 10 of Set 7 | yumbe
# Processing Record 11 of Set 7 | leningradskiy
# Processing Record 12 of Set 7 | east london
# Processing Record 13 of Set 7 | brae
# Processing Record 14 of Set 7 | mahibadhoo
# Processing Record 15 of Set 7 | madimba
# Processing Record 16 of Set 7 | kerman
# Processing Record 17 of Set 7 | nanortalik
# Processing Record 18 of Set 7 | lulea
# Processing Record 19 of Set 7 | santa maria del oro
# Processing Record 20 of Set 7 | soria
# Processing Record 21 of Set 7 | bogotol
# Processing Record 22 of Set 7 | lorengau
# Processing Record 23 of Set 7 | progreso
# Processing Record 24 of Set 7 | gold coast
# Processing Record 25 of Set 7 | dingle
# Processing Record 26 of Set 7 | zakamensk
# Processing Record 27 of Set 7 | capreol
# Processing Record 28 of Set 7 | mackay
# Processing Record 29 of Set 7 | capaci
# Processing Record 30 of Set 7 | kem
# Processing Record 31 of Set 7 | shahreza
# Processing Record 32 of Set 7 | la plata
# Processing Record 33 of Set 7 | shitanjing
# Processing Record 34 of Set 7 | korla
# Processing Record 35 of Set 7 | tete
# Processing Record 36 of Set 7 | blackfoot
# Processing Record 37 of Set 7 | nanakuli
# Processing Record 38 of Set 7 | domoni
# Processing Record 39 of Set 7 | lubango
# Processing Record 40 of Set 7 | college
# Processing Record 41 of Set 7 | port hardy
# Processing Record 42 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 7 | gorontalo
# Processing Record 44 of Set 7 | starodzhereliyevskaya
# Processing Record 45 of Set 7 | mandiana
# Processing Record 46 of Set 7 | taywarah
# Processing Record 47 of Set 7 | cidreira
# Processing Record 48 of Set 7 | sinnamary
# Processing Record 49 of Set 7 | esmeralda
# Processing Record 50 of Set 7 | amahai
# Processing Record 1 of Set 8 | tual
# Processing Record 2 of Set 8 | chara
# Processing Record 3 of Set 8 | labytnangi
# Processing Record 4 of Set 8 | baymak
# Processing Record 5 of Set 8 | najran
# Processing Record 6 of Set 8 | maniago
# Processing Record 7 of Set 8 | kaiyuan
# Processing Record 8 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 8 | nantucket
# Processing Record 10 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 11 of Set 8 | swift current
# Processing Record 12 of Set 8 | yulara
# Processing Record 13 of Set 8 | pandharpur
# Processing Record 14 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 8 | churumuco
# City not found. Skipping...
# Processing Record 17 of Set 8 | skibbereen
# Processing Record 18 of Set 8 | umm kaddadah
# Processing Record 19 of Set 8 | ewa beach
# Processing Record 20 of Set 8 | yushala
# Processing Record 21 of Set 8 | sawakin
# Processing Record 22 of Set 8 | portland
# Processing Record 23 of Set 8 | lata
# Processing Record 24 of Set 8 | tsagan aman
# Processing Record 25 of Set 8 | barrow
# Processing Record 26 of Set 8 | itaituba
# Processing Record 27 of Set 8 | plettenberg bay
# Processing Record 28 of Set 8 | ahipara
# Processing Record 29 of Set 8 | gravdal
# Processing Record 30 of Set 8 | half moon bay
# Processing Record 31 of Set 8 | mitsamiouli
# Processing Record 32 of Set 8 | aracati
# Processing Record 33 of Set 8 | manali
# Processing Record 34 of Set 8 | alyangula
# Processing Record 35 of Set 8 | ayorou
# Processing Record 36 of Set 8 | bridgeton
# Processing Record 37 of Set 8 | constitucion
# Processing Record 38 of Set 8 | smolensk
# Processing Record 39 of Set 8 | bhandara
# Processing Record 40 of Set 8 | sungai besar
# Processing Record 41 of Set 8 | aljezur
# Processing Record 42 of Set 8 | qasigiannguit
# Processing Record 43 of Set 8 | robertsport
# Processing Record 44 of Set 8 | ngunguru
# Processing Record 45 of Set 8 | carutapera
# Processing Record 46 of Set 8 | tazovskiy
# Processing Record 47 of Set 8 | santa isabel
# Processing Record 48 of Set 8 | high level
# Processing Record 49 of Set 8 | naze
# Processing Record 50 of Set 8 | ulundurpettai
# City not found. Skipping...
# Processing Record 1 of Set 9 | le port
# Processing Record 2 of Set 9 | grindavik
# Processing Record 3 of Set 9 | chabahar
# Processing Record 4 of Set 9 | ucluelet
# Processing Record 5 of Set 9 | kailua
# Processing Record 6 of Set 9 | harper
# Processing Record 7 of Set 9 | bud
# Processing Record 8 of Set 9 | excelsior springs
# Processing Record 9 of Set 9 | ferkessedougou
# Processing Record 10 of Set 9 | bucerias
# Processing Record 11 of Set 9 | koflach
# Processing Record 12 of Set 9 | aasiaat
# Processing Record 13 of Set 9 | san patricio
# Processing Record 14 of Set 9 | hohhot
# Processing Record 15 of Set 9 | wattegama
# Processing Record 16 of Set 9 | port lincoln
# Processing Record 17 of Set 9 | mako
# Processing Record 18 of Set 9 | olinda
# Processing Record 19 of Set 9 | bethel
# Processing Record 20 of Set 9 | bandarbeyla
# Processing Record 21 of Set 9 | kushiro
# Processing Record 22 of Set 9 | pokhara
# Processing Record 23 of Set 9 | gabu
# Processing Record 24 of Set 9 | shenjiamen
# Processing Record 25 of Set 9 | rosamorada
# Processing Record 26 of Set 9 | hamilton
# Processing Record 27 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 28 of Set 9 | pacific grove
# Processing Record 29 of Set 9 | aklavik
# Processing Record 30 of Set 9 | bengkalis
# City not found. Skipping...
# Processing Record 31 of Set 9 | coolum beach
# Processing Record 32 of Set 9 | pyshma
# Processing Record 33 of Set 9 | lucapa
# Processing Record 34 of Set 9 | giugliano in campania
# Processing Record 35 of Set 9 | acapulco
# Processing Record 36 of Set 9 | cutler
# Processing Record 37 of Set 9 | coulihaut
# City not found. Skipping...
# Processing Record 38 of Set 9 | farsund
# Processing Record 39 of Set 9 | andros town
# Processing Record 40 of Set 9 | tabas
# Processing Record 41 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 9 | nizhniy odes
# Processing Record 43 of Set 9 | gimli
# Processing Record 44 of Set 9 | changji
# Processing Record 45 of Set 9 | tumarbong
# Processing Record 46 of Set 9 | mount gambier
# Processing Record 47 of Set 9 | hoquiam
# Processing Record 48 of Set 9 | bafoulabe
# Processing Record 49 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 50 of Set 9 | forset
# City not found. Skipping...
# Processing Record 1 of Set 10 | sao filipe
# Processing Record 2 of Set 10 | stamsund
# City not found. Skipping...
# Processing Record 3 of Set 10 | koutsouras
# Processing Record 4 of Set 10 | longyearbyen
# Processing Record 5 of Set 10 | misratah
# Processing Record 6 of Set 10 | the valley
# Processing Record 7 of Set 10 | beaupre
# Processing Record 8 of Set 10 | conceicao da barra
# Processing Record 9 of Set 10 | salekhard
# Processing Record 10 of Set 10 | treinta y tres
# Processing Record 11 of Set 10 | buin
# Processing Record 12 of Set 10 | orumiyeh
# Processing Record 13 of Set 10 | santa rosa
# Processing Record 14 of Set 10 | abu samrah
# Processing Record 15 of Set 10 | igrim
# Processing Record 16 of Set 10 | chernyshevskiy
# Processing Record 17 of Set 10 | blyznyuky
# Processing Record 18 of Set 10 | comodoro rivadavia
# Processing Record 19 of Set 10 | nsanje
# Processing Record 20 of Set 10 | nome
# Processing Record 21 of Set 10 | gamba
# Processing Record 22 of Set 10 | te anau
# Processing Record 23 of Set 10 | mbini
# Processing Record 24 of Set 10 | devils lake
# Processing Record 25 of Set 10 | silver city
# Processing Record 26 of Set 10 | iracoubo
# Processing Record 27 of Set 10 | zhigansk
# Processing Record 28 of Set 10 | tessalit
# Processing Record 29 of Set 10 | gilgil
# City not found. Skipping...
# Processing Record 30 of Set 10 | taoudenni
# Processing Record 31 of Set 10 | balkanabat
# Processing Record 32 of Set 10 | sakakah
# Processing Record 33 of Set 10 | phalodi
# Processing Record 34 of Set 10 | guerrero negro
# Processing Record 35 of Set 10 | isfara
# Processing Record 36 of Set 10 | novobeysugskaya
# Processing Record 37 of Set 10 | vestmannaeyjar
# Processing Record 38 of Set 10 | bauta
# Processing Record 39 of Set 10 | qarqin
# Processing Record 40 of Set 10 | asau
# Processing Record 41 of Set 10 | vila velha
# Processing Record 42 of Set 10 | fort saint james
# Processing Record 43 of Set 10 | burnie
# Processing Record 44 of Set 10 | ngorongoro
# Processing Record 45 of Set 10 | maskinonge
# Processing Record 46 of Set 10 | willmar
# Processing Record 47 of Set 10 | labuhan
# Processing Record 48 of Set 10 | urucara
# Processing Record 49 of Set 10 | beringovskiy
# Processing Record 50 of Set 10 | northam
# Processing Record 1 of Set 11 | mehamn
# Processing Record 2 of Set 11 | yamada
# Processing Record 3 of Set 11 | kharp
# Processing Record 4 of Set 11 | bilibino
# Processing Record 5 of Set 11 | sergeyevka
# Processing Record 6 of Set 11 | minas
# Processing Record 7 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 11 | bonavista
# Processing Record 9 of Set 11 | worland
# Processing Record 10 of Set 11 | san policarpo
# Processing Record 11 of Set 11 | kloulklubed
# Processing Record 12 of Set 11 | sakmara
# Processing Record 13 of Set 11 | bowen
# Processing Record 14 of Set 11 | tucuma
# Processing Record 15 of Set 11 | nuuk
# Processing Record 16 of Set 11 | romanovka
# Processing Record 17 of Set 11 | villagarzon
# Processing Record 18 of Set 11 | ponta delgada
# Processing Record 19 of Set 11 | paamiut
# Processing Record 20 of Set 11 | shimoda
# Processing Record 21 of Set 11 | haines junction
# Processing Record 22 of Set 11 | shubarkuduk
# Processing Record 23 of Set 11 | axim
# Processing Record 24 of Set 11 | boende
# Processing Record 25 of Set 11 | naples
# Processing Record 26 of Set 11 | rincon
# Processing Record 27 of Set 11 | bushehr
# Processing Record 28 of Set 11 | west wendover
# Processing Record 29 of Set 11 | ohrid
# Processing Record 30 of Set 11 | qobustan
# Processing Record 31 of Set 11 | laguna
# Processing Record 32 of Set 11 | rorvik
# Processing Record 33 of Set 11 | guarumal
# Processing Record 34 of Set 11 | mlonggo
# Processing Record 35 of Set 11 | maniitsoq
# Processing Record 36 of Set 11 | codrington
# Processing Record 37 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 11 | turinsk
# Processing Record 39 of Set 11 | flin flon
# Processing Record 40 of Set 11 | luganville
# Processing Record 41 of Set 11 | finschhafen
# Processing Record 42 of Set 11 | sharlyk
# Processing Record 43 of Set 11 | necochea
# Processing Record 44 of Set 11 | saint joseph
# Processing Record 45 of Set 11 | acuna
# City not found. Skipping...
# Processing Record 46 of Set 11 | oistins
# Processing Record 47 of Set 11 | fonte boa
# Processing Record 48 of Set 11 | sarh
# Processing Record 49 of Set 11 | port blair
# Processing Record 50 of Set 11 | arman
# Processing Record 1 of Set 12 | biltine
# Processing Record 2 of Set 12 | ketchikan
# Processing Record 3 of Set 12 | corinth
# Processing Record 4 of Set 12 | ballina
# Processing Record 5 of Set 12 | kirillov
# Processing Record 6 of Set 12 | takoradi
# Processing Record 7 of Set 12 | winslow
# Processing Record 8 of Set 12 | taunggyi
# Processing Record 9 of Set 12 | zdvinsk
# Processing Record 10 of Set 12 | svinita
# Processing Record 11 of Set 12 | fairbanks
# Processing Record 12 of Set 12 | marinette
# Processing Record 13 of Set 12 | marsh harbour
# Processing Record 14 of Set 12 | luwuk
# Processing Record 15 of Set 12 | oytal
# Processing Record 16 of Set 12 | biloela
# Processing Record 17 of Set 12 | anloga
# Processing Record 18 of Set 12 | virginia beach
# Processing Record 19 of Set 12 | muravlenko
# Processing Record 20 of Set 12 | tilichiki
# Processing Record 21 of Set 12 | bubaque
# Processing Record 22 of Set 12 | puerto carreno
# Processing Record 23 of Set 12 | hami
# Processing Record 24 of Set 12 | andenes
# Processing Record 25 of Set 12 | hokitika
# Processing Record 26 of Set 12 | coos bay
# Processing Record 27 of Set 12 | coihaique
# Processing Record 28 of Set 12 | avera
# Processing Record 29 of Set 12 | tignere
# Processing Record 30 of Set 12 | tyazhinskiy
# Processing Record 31 of Set 12 | pangody
# Processing Record 32 of Set 12 | qurayyat
# Processing Record 33 of Set 12 | qui nhon
# Processing Record 34 of Set 12 | bolshaya sosnova
# Processing Record 35 of Set 12 | kudahuvadhoo
# Processing Record 36 of Set 12 | pafos
# Processing Record 37 of Set 12 | tromso
# Processing Record 38 of Set 12 | acworth
# Processing Record 39 of Set 12 | yanggu
# Processing Record 40 of Set 12 | pemba
# Processing Record 41 of Set 12 | souillac
# Processing Record 42 of Set 12 | gairo
# Processing Record 43 of Set 12 | safakulevo
# Processing Record 44 of Set 12 | grand forks
# Processing Record 45 of Set 12 | henties bay
# Processing Record 46 of Set 12 | ambilobe
# Processing Record 47 of Set 12 | kenai
# Processing Record 48 of Set 12 | san lorenzo
# Processing Record 49 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 50 of Set 12 | wundanyi
# Processing Record 1 of Set 13 | chicama
# Processing Record 2 of Set 13 | burns lake
# Processing Record 3 of Set 13 | noshiro
# Processing Record 4 of Set 13 | eyl
# Processing Record 5 of Set 13 | mathbaria
# Processing Record 6 of Set 13 | nyagan
# Processing Record 7 of Set 13 | villa carlos paz
# Processing Record 8 of Set 13 | chokwe
# Processing Record 9 of Set 13 | begoro
# Processing Record 10 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 13 | aranos
# Processing Record 12 of Set 13 | heywood
# Processing Record 13 of Set 13 | nouakchott
# Processing Record 14 of Set 13 | along
# Processing Record 15 of Set 13 | saint-augustin
# Processing Record 16 of Set 13 | madera
# Processing Record 17 of Set 13 | zhoucheng
# Processing Record 18 of Set 13 | roald
# Processing Record 19 of Set 13 | kanye
# Processing Record 20 of Set 13 | kirakira
# Processing Record 21 of Set 13 | marrakesh
# Processing Record 22 of Set 13 | hobyo
# Processing Record 23 of Set 13 | padang
# Processing Record 24 of Set 13 | nabire
# Processing Record 25 of Set 13 | gogrial
# Processing Record 26 of Set 13 | manjacaze
# Processing Record 27 of Set 13 | santa rita
# Processing Record 28 of Set 13 | belaya gora
# Processing Record 29 of Set 13 | stabat
# Processing Record 30 of Set 13 | boa viagem
# Processing Record 31 of Set 13 | phanom thuan
# Processing Record 32 of Set 13 | derzhavinsk
# Processing Record 33 of Set 13 | flinders
# Processing Record 34 of Set 13 | salalah
# Processing Record 35 of Set 13 | santa clara
# Processing Record 36 of Set 13 | krasnorechenskiy
# Processing Record 37 of Set 13 | mosquera
# Processing Record 38 of Set 13 | terrace bay
# Processing Record 39 of Set 13 | tsabong
# Processing Record 40 of Set 13 | huaicheng
# Processing Record 41 of Set 13 | qostanay
# Processing Record 42 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 43 of Set 13 | royan
# Processing Record 44 of Set 13 | saint-michel-des-saints
# Processing Record 45 of Set 13 | aykhal
# Processing Record 46 of Set 13 | dumas
# Processing Record 47 of Set 13 | ocala
# Processing Record 48 of Set 13 | winsum
# Processing Record 49 of Set 13 | sao miguel do araguaia
# Processing Record 50 of Set 13 | praya
# Processing Record 1 of Set 14 | gonzales
# Processing Record 2 of Set 14 | pergamino
# Processing Record 3 of Set 14 | manggar
# Processing Record 4 of Set 14 | pontes e lacerda
# Processing Record 5 of Set 14 | fallon
# Processing Record 6 of Set 14 | okhotsk
# Processing Record 7 of Set 14 | ortakoy
# Processing Record 8 of Set 14 | lar
# Processing Record 9 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 10 of Set 14 | luhyny
# Processing Record 11 of Set 14 | lompoc
# Processing Record 12 of Set 14 | kuito
# Processing Record 13 of Set 14 | tripoli
# Processing Record 14 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 14 | isla mujeres
# Processing Record 16 of Set 14 | praia da vitoria
# Processing Record 17 of Set 14 | miramar
# Processing Record 18 of Set 14 | kirksville
# Processing Record 19 of Set 14 | gigmoto
# Processing Record 20 of Set 14 | lampang
# Processing Record 21 of Set 14 | borovskoy
# Processing Record 22 of Set 14 | chala
# Processing Record 23 of Set 14 | ostrow mazowiecka
# Processing Record 24 of Set 14 | mlowo
# Processing Record 25 of Set 14 | bayan
# Processing Record 26 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 27 of Set 14 | sidi ali
# Processing Record 28 of Set 14 | marshfield
# Processing Record 29 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 30 of Set 14 | murphy
# Processing Record 31 of Set 14 | lanivtsi
# Processing Record 32 of Set 14 | ibra
# Processing Record 33 of Set 14 | abu dhabi
# Processing Record 34 of Set 14 | carballo
# Processing Record 35 of Set 14 | ixtapa
# Processing Record 36 of Set 14 | turukhansk
# Processing Record 37 of Set 14 | fengrun
# Processing Record 38 of Set 14 | sayalgudi
# City not found. Skipping...
# Processing Record 39 of Set 14 | vryburg
# Processing Record 40 of Set 14 | kalmunai
# Processing Record 41 of Set 14 | porto nacional
# Processing Record 42 of Set 14 | jalu
# Processing Record 43 of Set 14 | bathsheba
# Processing Record 44 of Set 14 | kota tinggi
# Processing Record 45 of Set 14 | bukama
# Processing Record 46 of Set 14 | esperance
# Processing Record 47 of Set 14 | mikun
# Processing Record 48 of Set 14 | mao
# Processing Record 49 of Set 14 | mugumu
# Processing Record 50 of Set 14 | solnechnyy
# Processing Record 1 of Set 15 | haldibari
# Processing Record 2 of Set 15 | mareeba
# Processing Record 3 of Set 15 | ailigandi
# Processing Record 4 of Set 15 | piacabucu
# Processing Record 5 of Set 15 | batagay
# Processing Record 6 of Set 15 | tateyama
# Processing Record 7 of Set 15 | eirunepe
# Processing Record 8 of Set 15 | ajaccio
# Processing Record 9 of Set 15 | dong hoi
# Processing Record 10 of Set 15 | zhanakorgan
# Processing Record 11 of Set 15 | mabaruma
# Processing Record 12 of Set 15 | pochutla
# Processing Record 13 of Set 15 | rundu
# Processing Record 14 of Set 15 | puerto madryn
# Processing Record 15 of Set 15 | sobradinho
# Processing Record 16 of Set 15 | truro
# Processing Record 17 of Set 15 | almonte
# Processing Record 18 of Set 15 | ayagoz
# Processing Record 19 of Set 15 | porosozero
# Processing Record 20 of Set 15 | longjiang
# Processing Record 21 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 22 of Set 15 | phuket
# Processing Record 23 of Set 15 | andarab
# City not found. Skipping...
# Processing Record 24 of Set 15 | carnot
# Processing Record 25 of Set 15 | gisborne
# Processing Record 26 of Set 15 | roebourne
# Processing Record 27 of Set 15 | talnakh
# Processing Record 28 of Set 15 | dilla
# Processing Record 29 of Set 15 | ayr
# Processing Record 30 of Set 15 | mayo
# Processing Record 31 of Set 15 | goryachegorsk
# Processing Record 32 of Set 15 | praia
# Processing Record 33 of Set 15 | aleksandrov gay
# Processing Record 34 of Set 15 | adelaide
# Processing Record 35 of Set 15 | tougue
# Processing Record 36 of Set 15 | superior
# Processing Record 37 of Set 15 | amapa
# Processing Record 38 of Set 15 | terrace
# Processing Record 39 of Set 15 | lakselv
# Processing Record 40 of Set 15 | envira
# Processing Record 41 of Set 15 | calvinia
# Processing Record 42 of Set 15 | kurchum
# Processing Record 43 of Set 15 | balabac
# Processing Record 44 of Set 15 | danszentmiklos
# Processing Record 45 of Set 15 | charters towers
# Processing Record 46 of Set 15 | severo-kurilsk
# Processing Record 47 of Set 15 | burley
# Processing Record 48 of Set 15 | bakel
# Processing Record 49 of Set 15 | kurtamysh
# Processing Record 50 of Set 15 | villa bruzual
# Processing Record 1 of Set 16 | fukue
# Processing Record 2 of Set 16 | ginda
# Processing Record 3 of Set 16 | sola
# Processing Record 4 of Set 16 | farmington
# Processing Record 5 of Set 16 | baoqing
# Processing Record 6 of Set 16 | svetlyy
# Processing Record 7 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 16 | samarai
# Processing Record 9 of Set 16 | damghan
# Processing Record 10 of Set 16 | vanavara
# Processing Record 11 of Set 16 | bilma
# Processing Record 12 of Set 16 | ziarat
# Processing Record 13 of Set 16 | cotonou
# Processing Record 14 of Set 16 | sawtell
# Processing Record 15 of Set 16 | porto novo
# Processing Record 16 of Set 16 | novyy urengoy
# Processing Record 17 of Set 16 | kavaratti
# Processing Record 18 of Set 16 | cooma
# Processing Record 19 of Set 16 | dunedin
# Processing Record 20 of Set 16 | nago
# Processing Record 21 of Set 16 | teahupoo
# Processing Record 22 of Set 16 | fomboni
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea -23.1203 -134.9692     78.13        72          75
# 1   Port Alfred -33.5906   26.8910     65.91        55          96
# 2    Chokurdakh  70.6333  147.9167    -10.95        97          60
# 3  Punta Arenas -53.1500  -70.9167     51.80        71          40
# 4      Meulaboh   4.1363   96.1285     77.81        83         100
# 5  Puerto Ayora  -0.7393  -90.3518     79.00        89          75
# 6    Bredasdorp -34.5322   20.0403     64.40        59          19
# 7       Golspie  57.9727   -3.9780     36.00        90          47
# 8         Kapaa  22.0752 -159.3190     77.00        73          90
# 9      Ust-Nera  64.5667  143.2000      8.40        89         100
#
#    Wind Speed Country Current Description
# 0        7.49      PF       broken clouds
# 1       22.21      ZA     overcast clouds
# 2        2.06      RU       broken clouds
# 3        9.22      CL    scattered clouds
# 4        1.81      ID     overcast clouds
# 5        9.22      EC          light rain
# 6       12.66      ZA          few clouds
# 7        3.00      GB    scattered clouds
# 8        9.22      US          light rain
# 9        5.79      RU     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
